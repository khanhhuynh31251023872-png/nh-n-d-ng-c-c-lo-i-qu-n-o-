# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

print("Số ảnh train:", x_train.shape)
print("Số ảnh test:", x_test.shape)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Số ảnh train: (60000, 28, 28)
# Số ảnh test: (10000, 28, 28)

# %%
class_names = [
    "Áo thun / T-shirt",
    "Quần dài / Trouser",
    "Áo len / Pullover",
    "Váy / Dress",
    "Áo khoác / Coat",
    "Dép / Sandal",
    "Áo sơ mi / Shirt",
    "Giày sneaker",
    "Túi xách / Bag",
    "Boot / Ankle boot"
]

# %%
plt.figure(figsize=(8, 8))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(x_train[i], cmap="gray")
    plt.title(class_names[y_train[i]])
    plt.axis("off")

plt.show()

# %%
x_train = x_train.reshape(-1, 28, 28, 1) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1) / 255.0

y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

print(x_train.shape)
print(y_train_cat.shape)
# Out:
# (60000, 28, 28, 1)
# (60000, 10)

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),

    Conv2D(64, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),

    Flatten(),
    Dense(128, activation="relu"),
    Dense(10, activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
history = model.fit(
    x_train,
    y_train_cat,
    epochs=5,
    batch_size=64,
    validation_data=(x_test, y_test_cat)
)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 33s 33ms/step - accuracy: 0.8231 - loss: 0.4895 - val_accuracy: 0.8628 - val_loss: 0.3865
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.8822 - loss: 0.3249 - val_accuracy: 0.8870 - val_loss: 0.3221
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 32s 34ms/step - accuracy: 0.8996 - loss: 0.2755 - val_accuracy: 0.8883 - val_loss: 0.3097
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 31s 33ms/step - accuracy: 0.9091 - loss: 0.2461 - val_accuracy: 0.9006 - val_loss: 0.2671
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.9191 - loss: 0.2200 - val_accuracy: 0.9073 - val_loss: 0.2575

# %%
test_loss, test_acc = model.evaluate(x_test, y_test_cat)

print("Độ chính xác:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9073 - loss: 0.2575
# Độ chính xác: 0.9072999954223633

# %%
from IPython.display import display, HTML
from google.colab.output import eval_js
from base64 import b64decode

def draw_canvas(filename="drawing.png", width=280, height=280):
    js = f"""
    async function drawCanvas() {{
        const div = document.createElement('div');

        const canvas = document.createElement('canvas');
        canvas.width = {width};
        canvas.height = {height};
        canvas.style.border = '2px solid black';
        canvas.style.cursor = 'crosshair';

        const ctx = canvas.getContext('2d');
        ctx.fillStyle = 'black';
        ctx.fillRect(0, 0, canvas.width, canvas.height);

        ctx.strokeStyle = 'white';
        ctx.lineWidth = 18;
        ctx.lineCap = 'round';

        let drawing = false;

        function getPos(e) {{
            const rect = canvas.getBoundingClientRect();
            return {{
                x: e.clientX - rect.left,
                y: e.clientY - rect.top
            }};
        }}

        canvas.addEventListener('mousedown', function(e) {{
            drawing = true;
            const pos = getPos(e);
            ctx.beginPath();
            ctx.moveTo(pos.x, pos.y);
        }});

        canvas.addEventListener('mousemove', function(e) {{
            if (!drawing) return;
            const pos = getPos(e);
            ctx.lineTo(pos.x, pos.y);
            ctx.stroke();
        }});

        canvas.addEventListener('mouseup', function(e) {{
            drawing = false;
        }});

        canvas.addEventListener('mouseleave', function(e) {{
            drawing = false;
        }});

        const saveButton = document.createElement('button');
        saveButton.textContent = 'Lưu hình để dự đoán';
        saveButton.style.margin = '10px';
        saveButton.style.padding = '8px';

        const clearButton = document.createElement('button');
        clearButton.textContent = 'Xóa vẽ lại';
        clearButton.style.margin = '10px';
        clearButton.style.padding = '8px';

        clearButton.onclick = function() {{
            ctx.fillStyle = 'black';
            ctx.fillRect(0, 0, canvas.width, canvas.height);
            ctx.strokeStyle = 'white';
        }};

        div.appendChild(canvas);
        div.appendChild(document.createElement('br'));
        div.appendChild(saveButton);
        div.appendChild(clearButton);

        document.body.appendChild(div);

        await new Promise((resolve) => saveButton.onclick = resolve);

        return canvas.toDataURL('image/png');
    }}

    drawCanvas()
    """

    data = eval_js(js)
    binary = b64decode(data.split(',')[1])

    with open(filename, "wb") as f:
        f.write(binary)

    return filename

# %%
file_path = draw_canvas()
print("Đã lưu hình:", file_path)
# Out:
# Đã lưu hình: drawing.png

# %%
from PIL import Image

img = Image.open(file_path).convert("L")

plt.imshow(img, cmap="gray")
plt.axis("off")
plt.show()

# %%
from PIL import Image
import numpy as np

def predict_drawing(file_path):
    img = Image.open(file_path).convert("L")

    # Resize về 28x28 giống Fashion MNIST
    img = img.resize((28, 28))

    # Chuyển thành numpy array
    img_array = np.array(img)

    # Chuẩn hóa
    img_array = img_array / 255.0

    # Đưa về đúng shape của model
    img_array = img_array.reshape(1, 28, 28, 1)

    # Dự đoán
    prediction = model.predict(img_array)
    label = np.argmax(prediction)
    confidence = np.max(prediction)

    print("Kết quả dự đoán:", class_names[label])
    print("Độ tin cậy:", round(confidence * 100, 2), "%")

    # Hiển thị xác suất từng loại
    for i, prob in enumerate(prediction[0]):
        print(class_names[i], ":", round(prob * 100, 2), "%")

predict_drawing(file_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Kết quả dự đoán: Dép / Sandal
# Độ tin cậy: 64.68 %
# Áo thun / T-shirt : 1.4 %
# Quần dài / Trouser : 0.07 %
# Áo len / Pullover : 0.01 %
# Váy / Dress : 0.03 %
# Áo khoác / Coat : 0.01 %
# Dép / Sandal : 64.68 %
# Áo sơ mi / Shirt : 0.01 %
# Giày sneaker : 0.05 %
# Túi xách / Bag : 33.74 %
# Boot / Ankle boot : 0.0 %

# %%
file_path = draw_canvas()

# %%
predict_drawing(file_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Kết quả dự đoán: Áo thun / T-shirt
# Độ tin cậy: 59.6 %
# Áo thun / T-shirt : 59.6 %
# Quần dài / Trouser : 0.0 %
# Áo len / Pullover : 0.04 %
# Váy / Dress : 0.0 %
# Áo khoác / Coat : 0.0 %
# Dép / Sandal : 0.89 %
# Áo sơ mi / Shirt : 2.12 %
# Giày sneaker : 0.0 %
# Túi xách / Bag : 37.36 %
# Boot / Ankle boot : 0.0 %
